# %%
import pandas as pd

# %%
vendas_bd = pd.read_excel('vendas.xlsx')
display(vendas_bd.head(10))
# Out:
#    Código Venda       Data                     ID Loja  \
# 0             1 2019-01-01          Iguatemi Esplanada
# 1             1 2019-01-01          Iguatemi Esplanada
# 2             1 2019-01-01          Iguatemi Esplanada
# 3             2 2019-01-02              Norte Shopping
# 4             2 2019-01-02              Norte Shopping
# 5             3 2019-01-02  Rio Mar Shopping Fortaleza
# 6             5 2019-01-02              Shopping Barra
# 7             6 2019-01-02         Shopping Ibirapuera
# 8             7 2019-01-02              Norte Shopping
# 9             7 2019-01-02              Norte Shopping
#
#                   Produto  Quantidade  Valor Unitário  Valor Final
# 0          Sapato Estampa           1             358          358
# 1                Camiseta           2             180          360
# 2           Sapato Xadrez           1             368          368
# 3                 Relógio           3             200          600
# ...

# %%
print(vendas_bd.shape)
# Out:
# (93910, 7)

# %%
print(vendas_bd.describe())
# Out:
#        Código Venda    Quantidade  Valor Unitário   Valor Final
# count  93910.000000  93910.000000    93910.000000  93910.000000
# mean   32464.762155      2.166553      191.725886    414.862656
# std    18809.007093      1.258732      145.215519    434.846228
# min        1.000000      1.000000       30.000000     30.000000
# 25%    16204.000000      1.000000      100.000000    156.000000
# 50%    32367.000000      2.000000      155.000000    274.000000
# 75%    48793.750000      3.000000      248.000000    524.000000
# max    65014.000000      5.000000      750.000000   3750.000000

# %%
display(vendas_bd.describe())
# Out:
#        Código Venda    Quantidade  Valor Unitário   Valor Final
# count  93910.000000  93910.000000    93910.000000  93910.000000
# mean   32464.762155      2.166553      191.725886    414.862656
# std    18809.007093      1.258732      145.215519    434.846228
# min        1.000000      1.000000       30.000000     30.000000
# 25%    16204.000000      1.000000      100.000000    156.000000
# 50%    32367.000000      2.000000      155.000000    274.000000
# 75%    48793.750000      3.000000      248.000000    524.000000
# max    65014.000000      5.000000      750.000000   3750.000000

# %%
produtos = vendas_bd[['Produto', 'Valor Final']]

# %%
display(produtos)
# Out:
#                  Produto  Valor Final
# 0         Sapato Estampa          358
# 1               Camiseta          360
# 2          Sapato Xadrez          368
# 3                Relógio          600
# 4           Chinelo Liso           71
# ...                  ...          ...
# 93905     Mochila Xadrez          566
# 93906  Pulseira Listrado          158
# 93907     Cueca Listrado          201
# 93908     Pulseira Linho          570
# 93909      Casaco Xadrez         1036
#
# [93910 rows x 2 columns]

# %%
display(vendas_bd.loc[vendas_bd['Produto'] == 'Camiseta'])
# Out:
#        Código Venda       Data                       ID Loja   Produto  \
# 1                 1 2019-01-01            Iguatemi Esplanada  Camiseta
# 15               11 2019-01-02               Shopping Recife  Camiseta
# 119              93 2019-01-02  Novo Shopping Ribeirão Preto  Camiseta
# 206             148 2019-01-02    Shopping Center Interlagos  Camiseta
# 276             199 2019-01-02     Passei das Águas Shopping  Camiseta
# ...             ...        ...                           ...       ...
# 92991         64379 2019-11-27               Shopping Recife  Camiseta
# 93050         64427 2019-11-27     Passei das Águas Shopping  Camiseta
# 93071         64443 2019-11-28                Shopping Barra  Camiseta
# 93577         64787 2019-11-29     Passei das Águas Shopping  Camiseta
# 93900         65009 2019-11-30                Shopping Barra  Camiseta
#
#        Quantidade  Valor Unitário  Valor Final
# 1               2             180          360
# ...

# %%
camisetas = vendas_bd.loc[vendas_bd['Produto'] == 'Camiseta', ["ID Loja", "Quantidade", "Valor Final"]]

# %%
display(camisetas)
# Out:
#                             ID Loja  Quantidade  Valor Final
# 1                Iguatemi Esplanada           2          360
# 15                  Shopping Recife           1          180
# 119    Novo Shopping Ribeirão Preto           1          180
# 206      Shopping Center Interlagos           2          360
# 276       Passei das Águas Shopping           2          360
# ...                             ...         ...          ...
# 92991               Shopping Recife           1          180
# 93050     Passei das Águas Shopping           2          360
# 93071                Shopping Barra           1          180
# 93577     Passei das Águas Shopping           5          900
# 93900                Shopping Barra           2          360
#
# [783 rows x 3 columns]

# %%
vendas_bd['Lucro'] = vendas_bd['Valor Final'] * 0.3
display(vendas_bd)
# Out:
#        Código Venda       Data              ID Loja            Produto  \
# 0                 1 2019-01-01   Iguatemi Esplanada     Sapato Estampa
# 1                 1 2019-01-01   Iguatemi Esplanada           Camiseta
# 2                 1 2019-01-01   Iguatemi Esplanada      Sapato Xadrez
# 3                 2 2019-01-02       Norte Shopping            Relógio
# 4                 2 2019-01-02       Norte Shopping       Chinelo Liso
# ...             ...        ...                  ...                ...
# 93905         65012 2019-11-30  Shopping Vila Velha     Mochila Xadrez
# 93906         65013 2019-11-30    Ribeirão Shopping  Pulseira Listrado
# 93907         65013 2019-11-30    Ribeirão Shopping     Cueca Listrado
# 93908         65014 2019-11-30     Shopping Morumbi     Pulseira Linho
# 93909         65014 2019-11-30     Shopping Morumbi      Casaco Xadrez
#
#        Quantidade  Valor Unitário  Valor Final  Lucro
# 0               1             358          358  107.4
# ...

# %%
vendas_dz_bd = pd.read_excel('Vendas - Dez.xlsx')

# %%
display(vendas_dz_bd)
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0            65014 2019-12-01            Shopping Morumbi    Sunga Listrado
# 1            65014 2019-12-01            Shopping Morumbi   Casaco Listrado
# 2            65016 2019-12-01           Iguatemi Campinas   Sapato Listrado
# 3            65016 2019-12-01           Iguatemi Campinas            Casaco
# 4            65017 2019-12-01          Shopping SP Market        Gorro Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final
# ...

# %%
vendas_bd = vendas_bd.append(vendas_dz_bd)
#Vai ser descontinuado
# Out:
# C:\Users\joaof\AppData\Local\Temp\ipykernel_11376\580737668.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vendas_bd = vendas_bd.append(vendas_dz_bd)

# %%
display(vendas_bd)
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0                1 2019-01-01          Iguatemi Esplanada    Sapato Estampa
# 1                1 2019-01-01          Iguatemi Esplanada          Camiseta
# 2                1 2019-01-01          Iguatemi Esplanada     Sapato Xadrez
# 3                2 2019-01-02              Norte Shopping           Relógio
# 4                2 2019-01-02              Norte Shopping      Chinelo Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final  Lucro
# ...

# %%
vendas_bd = vendas_bd.dropna()
#apaga linhas com valores vazios

# %%
display(vendas_bd)
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0                1 2019-01-01          Iguatemi Esplanada    Sapato Estampa
# 1                1 2019-01-01          Iguatemi Esplanada          Camiseta
# 2                1 2019-01-01          Iguatemi Esplanada     Sapato Xadrez
# 3                2 2019-01-02              Norte Shopping           Relógio
# 4                2 2019-01-02              Norte Shopping      Chinelo Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final  Lucro
# ...

# %%
vendas_bd['Lucro'] = vendas_bd['Lucro'].fillna(vendas_bd['Lucro'].mean())
#prenche valores vazios

# %%
display(vendas_bd)
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0                1 2019-01-01          Iguatemi Esplanada    Sapato Estampa
# 1                1 2019-01-01          Iguatemi Esplanada          Camiseta
# 2                1 2019-01-01          Iguatemi Esplanada     Sapato Xadrez
# 3                2 2019-01-02              Norte Shopping           Relógio
# 4                2 2019-01-02              Norte Shopping      Chinelo Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
# ...

# %%
receita = vendas_bd['ID Loja'].value_counts()
#contar os valores de uma coluna

# %%
display(receita)
# Out:
# Shopping Vila Velha                 4234
# Palladium Shopping Curitiba         4210
# Norte Shopping                      4179
# Rio Mar Shopping Fortaleza          4118
# Bourbon Shopping SP                 4116
# Iguatemi Campinas                   4108
# Rio Mar Recife                      4099
# Shopping Center Leste Aricanduva    4093
# Shopping SP Market                  4080
# Shopping Ibirapuera                 4051
# Novo Shopping Ribeirão Preto        4049
# Ribeirão Shopping                   4048
# Salvador Shopping                   4030
# Shopping Center Interlagos          4021
# Shopping Iguatemi Fortaleza         4021
# Center Shopping Uberlândia          4013
# Shopping Eldorado                   4002
# Passei das Águas Shopping           4000
# Shopping União de Osasco            3995
# Iguatemi Esplanada                  3980
# Shopping Barra                      3962
# Shopping Morumbi                    3960
# Parque Dom Pedro Shopping           3902
# ...

# %%
venda_produto = vendas_bd[['Produto', 'Valor Final']].groupby('Produto').sum()

# %%
display(venda_produto)
# Out:
#                   Valor Final
# Produto
# Bermuda                272250
# Bermuda Estampa        291694
# Bermuda Linho          394680
# Bermuda Liso           275692
# Bermuda Listrado       293237
# ...                       ...
# Tênis Estampa          457728
# Tênis Linho            538608
# Tênis Liso             474544
# Tênis Listrado         481032
# Tênis Xadrez           459725
#
# [120 rows x 1 columns]

# %%
display(venda_produto.shape)
# Out:
# (120,)
